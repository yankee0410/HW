# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Getting started with neural networks: Classification and regression

# %% [markdown]
# ## Classifying movie reviews: A binary classification example

# %% [markdown]
# ### The IMDB dataset

# %% [markdown]
# **Loading the IMDB dataset**

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# **Decoding reviews back to text**

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])
decoded_review = " ".join(
    [reverse_word_index.get(i - 3, "?") for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the integer sequences via multi-hot encoding**

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# **Training your model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 5s 40ms/step - loss: 0.5300 - accuracy: 0.7765 - val_loss: 0.4004 - val_accuracy: 0.8677
# Epoch 2/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3178 - accuracy: 0.9017 - val_loss: 0.3114 - val_accuracy: 0.8892
# Epoch 3/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.2342 - accuracy: 0.9263 - val_loss: 0.2894 - val_accuracy: 0.8860
# Epoch 4/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.1858 - accuracy: 0.9400 - val_loss: 0.2779 - val_accuracy: 0.8895
# Epoch 5/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1478 - accuracy: 0.9531 - val_loss: 0.3272 - val_accuracy: 0.8758
# Epoch 6/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.1192 - accuracy: 0.9623 - val_loss: 0.3279 - val_accuracy: 0.8768
# Epoch 7/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0997 - accuracy: 0.9710 - val_loss: 0.3666 - val_accuracy: 0.8691
# Epoch 8/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0854 - accuracy: 0.9762 - val_loss: 0.3467 - val_accuracy: 0.8766
# Epoch 9/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0704 - accuracy: 0.9806 - val_loss: 0.3495 - val_accuracy: 0.8806
# Epoch 10/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0635 - accuracy: 0.9839 - val_loss: 0.3802 - val_accuracy: 0.8760
# Epoch 11/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0515 - accuracy: 0.9877 - val_loss: 0.3938 - val_accuracy: 0.8763
# Epoch 12/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0440 - accuracy: 0.9903 - val_loss: 0.4196 - val_accuracy: 0.8759
# Epoch 13/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0387 - accuracy: 0.9915 - val_loss: 0.4495 - val_accuracy: 0.8706
# Epoch 14/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0305 - accuracy: 0.9943 - val_loss: 0.4696 - val_accuracy: 0.8714
# Epoch 15/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0243 - accuracy: 0.9961 - val_loss: 0.5064 - val_accuracy: 0.8699
# Epoch 16/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0211 - accuracy: 0.9967 - val_loss: 0.5300 - val_accuracy: 0.8701
# Epoch 17/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0166 - accuracy: 0.9977 - val_loss: 0.5615 - val_accuracy: 0.8680
# Epoch 18/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0140 - accuracy: 0.9978 - val_loss: 0.6173 - val_accuracy: 0.8638
# Epoch 19/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0123 - accuracy: 0.9981 - val_loss: 0.6238 - val_accuracy: 0.8667
# Epoch 20/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.6560 - val_accuracy: 0.8663

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# **Plotting the training and validation loss**

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.4495 - accuracy: 0.8265
# Epoch 2/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.2585 - accuracy: 0.9087
# Epoch 3/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.1971 - accuracy: 0.9298
# Epoch 4/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.1650 - accuracy: 0.9415
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2951 - accuracy: 0.8831

# %%
results
# Out:
# [0.2950969934463501, 0.8831200003623962]

# %% [markdown]
# ### Using a trained model to generate predictions on new data

# %%
model.predict(x_test)
# Out:
# array([[0.16057882],
#        [0.9998091 ],
#        [0.980414  ],
#        ...,
#        [0.14423925],
#        [0.08273999],
#        [0.72946066]], dtype=float32)

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Classifying newswires: A multiclass classification example

# %% [markdown]
# ### The Reuters dataset

# %% [markdown]
# **Loading the Reuters dataset**

# %%
from tensorflow.keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
    num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# 2121728/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# **Decoding newswires back to text**

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = " ".join([reverse_word_index.get(i - 3, "?") for i in
    train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step
# 565248/550378 [==============================] - 0s 0us/step

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Encoding the input data**

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %% [markdown]
# **Encoding the labels**

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results
y_train = to_one_hot(train_labels)
y_test = to_one_hot(test_labels)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

# %% [markdown]
# **Compiling the model**

# %%
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Validating your approach

# %% [markdown]
# **Setting aside a validation set**

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %% [markdown]
# **Training the model**

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 28ms/step - loss: 2.5815 - accuracy: 0.5272 - val_loss: 1.7498 - val_accuracy: 0.6580
# Epoch 2/20
# 16/16 [==============================] - 0s 15ms/step - loss: 1.4115 - accuracy: 0.7023 - val_loss: 1.3135 - val_accuracy: 0.7120
# Epoch 3/20
# 16/16 [==============================] - 0s 15ms/step - loss: 1.0431 - accuracy: 0.7755 - val_loss: 1.1238 - val_accuracy: 0.7600
# Epoch 4/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.8157 - accuracy: 0.8326 - val_loss: 1.0404 - val_accuracy: 0.7790
# Epoch 5/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6472 - accuracy: 0.8677 - val_loss: 0.9512 - val_accuracy: 0.8120
# Epoch 6/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.5133 - accuracy: 0.8950 - val_loss: 0.9253 - val_accuracy: 0.8130
# Epoch 7/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4121 - accuracy: 0.9158 - val_loss: 0.9032 - val_accuracy: 0.8210
# Epoch 8/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3340 - accuracy: 0.9298 - val_loss: 0.8839 - val_accuracy: 0.8230
# Epoch 9/20
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2777 - accuracy: 0.9406 - val_loss: 0.8965 - val_accuracy: 0.8160
# Epoch 10/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2291 - accuracy: 0.9489 - val_loss: 0.9232 - val_accuracy: 0.8170
# Epoch 11/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2052 - accuracy: 0.9506 - val_loss: 0.9234 - val_accuracy: 0.8200
# Epoch 12/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1791 - accuracy: 0.9504 - val_loss: 0.9218 - val_accuracy: 0.8130
# Epoch 13/20
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1569 - accuracy: 0.9560 - val_loss: 0.9422 - val_accuracy: 0.8160
# Epoch 14/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1468 - accuracy: 0.9549 - val_loss: 1.0298 - val_accuracy: 0.8080
# Epoch 15/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1362 - accuracy: 0.9578 - val_loss: 1.0623 - val_accuracy: 0.7960
# Epoch 16/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1265 - accuracy: 0.9558 - val_loss: 1.0227 - val_accuracy: 0.8030
# Epoch 17/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1236 - accuracy: 0.9577 - val_loss: 1.0051 - val_accuracy: 0.8150
# Epoch 18/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1177 - accuracy: 0.9565 - val_loss: 1.0865 - val_accuracy: 0.8040
# Epoch 19/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1180 - accuracy: 0.9572 - val_loss: 1.0513 - val_accuracy: 0.8130
# Epoch 20/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1110 - accuracy: 0.9569 - val_loss: 1.0948 - val_accuracy: 0.8000

# %% [markdown]
# **Plotting the training and validation loss**

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Plotting the training and validation accuracy**

# %%
plt.clf()
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# **Retraining a model from scratch**

# %%
model = keras.Sequential([
  layers.Dense(64, activation="relu"),
  layers.Dense(64, activation="relu"),
  layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,
          y_train,
          epochs=9,
          batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/9
# 18/18 [==============================] - 1s 12ms/step - loss: 2.4157 - accuracy: 0.5337
# Epoch 2/9
# 18/18 [==============================] - 0s 12ms/step - loss: 1.3108 - accuracy: 0.7216
# Epoch 3/9
# 18/18 [==============================] - 0s 13ms/step - loss: 0.9795 - accuracy: 0.7899
# Epoch 4/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.7674 - accuracy: 0.8372
# Epoch 5/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6051 - accuracy: 0.8695
# Epoch 6/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.4788 - accuracy: 0.8979
# Epoch 7/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3928 - accuracy: 0.9144
# Epoch 8/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3182 - accuracy: 0.9316
# Epoch 9/9
# 18/18 [==============================] - 0s 12ms/step - loss: 0.2684 - accuracy: 0.9398
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9641 - accuracy: 0.8001

# %%
results
# Out:
# [0.9640830755233765, 0.8000890612602234]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
hits_array.mean()
# Out:
# 0.18699910952804988

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0000001

# %%
np.argmax(predictions[0])
# Out:
# 4

# %% [markdown]
# ### A different way to handle the labels and the loss

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### The importance of having sufficiently large intermediate layers

# %% [markdown]
# **A model with an information bottleneck**

# %%
model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(46, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.4342 - accuracy: 0.5068 - val_loss: 1.7563 - val_accuracy: 0.5450
# Epoch 2/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.5419 - accuracy: 0.5859 - val_loss: 1.4926 - val_accuracy: 0.6080
# Epoch 3/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.2862 - accuracy: 0.6540 - val_loss: 1.3922 - val_accuracy: 0.6700
# Epoch 4/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.1289 - accuracy: 0.7071 - val_loss: 1.3390 - val_accuracy: 0.6870
# Epoch 5/20
# 63/63 [==============================] - 0s 6ms/step - loss: 1.0120 - accuracy: 0.7420 - val_loss: 1.3079 - val_accuracy: 0.6980
# Epoch 6/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.9176 - accuracy: 0.7685 - val_loss: 1.2994 - val_accuracy: 0.7080
# Epoch 7/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.8389 - accuracy: 0.7838 - val_loss: 1.3003 - val_accuracy: 0.7080
# Epoch 8/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7735 - accuracy: 0.7940 - val_loss: 1.3264 - val_accuracy: 0.7020
# Epoch 9/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.7168 - accuracy: 0.7995 - val_loss: 1.3727 - val_accuracy: 0.7040
# Epoch 10/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6705 - accuracy: 0.8049 - val_loss: 1.3957 - val_accuracy: 0.7010
# Epoch 11/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6296 - accuracy: 0.8162 - val_loss: 1.4327 - val_accuracy: 0.7050
# Epoch 12/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5918 - accuracy: 0.8296 - val_loss: 1.4720 - val_accuracy: 0.7080
# Epoch 13/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.5577 - accuracy: 0.8429 - val_loss: 1.5321 - val_accuracy: 0.7000
# Epoch 14/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5295 - accuracy: 0.8525 - val_loss: 1.5749 - val_accuracy: 0.7050
# Epoch 15/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.5006 - accuracy: 0.8598 - val_loss: 1.6171 - val_accuracy: 0.7070
# Epoch 16/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4755 - accuracy: 0.8641 - val_loss: 1.6776 - val_accuracy: 0.7020
# Epoch 17/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4571 - accuracy: 0.8664 - val_loss: 1.6970 - val_accuracy: 0.7060
# Epoch 18/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.8702 - val_loss: 1.8765 - val_accuracy: 0.7000
# Epoch 19/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.4183 - accuracy: 0.8780 - val_loss: 1.8761 - val_accuracy: 0.7050
# Epoch 20/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.4057 - accuracy: 0.8836 - val_loss: 1.9309 - val_accuracy: 0.7030

# %% [markdown]
# ### Further experiments

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Predicting house prices: A regression example

# %% [markdown]
# ### The Boston Housing Price dataset

# %% [markdown]
# **Loading the Boston housing dataset**

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step
# 65536/57026 [==================================] - 0s 0us/step

# %%
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
#        19.6, 23.9, 24.5, 25. , 19.9, 17.2, 24.6, 13.5, 26.6, 21.4, 11.9,
#        22.6, 19.6,  8.5, 23.7, 23.1, 22.4, 20.5, 23.6, 18.4, 35.2, 23.1,
#        27.9, 20.6, 23.7, 28. , 13.6, 27.1, 23.6, 20.6, 18.2, 21.7, 17.1,
#         8.4, 25.3, 13.8, 22.2, 18.4, 20.7, 31.6, 30.5, 20.3,  8.8, 19.2,
#        19.4, 23.1, 23. , 14.8, 48.8, 22.6, 33.4, 21.1, 13.6, 32.2, 13.1,
#        23.4, 18.9, 23.9, 11.8, 23.3, 22.8, 19.6, 16.7, 13.4, 22.2, 20.4,
#        21.8, 26.4, 14.9, 24.1, 23.8, 12.3, 29.1, 21. , 19.5, 23.3, 23.8,
#        17.8, 11.5, 21.7, 19.9, 25. , 33.4, 28.5, 21.4, 24.3, 27.5, 33.1,
#        16.2, 23.3, 48.3, 22.9, 22.8, 13.1, 12.7, 22.6, 15. , 15.3, 10.5,
#        24. , 18.5, 21.7, 19.5, 33.2, 23.2,  5. , 19.1, 12.7, 22.3, 10.2,
#        13.9, 16.3, 17. , 20.1, 29.9, 17.2, 37.3, 45.4, 17.8, 23.2, 29. ,
#        22. , 18. , 17.4, 34.6, 20.1, 25. , 15.6, 24.8, 28.2, 21.2, 21.4,
#        23.8, 31. , 26.2, 17.4, 37.9, 17.5, 20. ,  8.3, 23.9,  8.4, 13.8,
#         7.2, 11.7, 17.1, 21.6, 50. , 16.1, 20.4, 20.6, 21.4, 20.6, 36.5,
#         8.5, 24.8, 10.8, 21.9, 17.3, 18.9, 36.2, 14.9, 18.2, 33.3, 21.8,
#        19.7, 31.6, 24.8, 19.4, 22.8,  7.5, 44.8, 16.8, 18.7, 50. , 50. ,
#        19.5, 20.1, 50. , 17.2, 20.8, 19.3, 41.3, 20.4, 20.5, 13.8, 16.5,
#        23.9, 20.6, 31.5, 23.3, 16.8, 14. , 33.8, 36.1, 12.8, 18.3, 18.7,
#        19.1, 29. , 30.1, 50. , 50. , 22. , 11.9, 37.6, 50. , 22.7, 20.8,
#        23.5, 27.9, 50. , 19.3, 23.9, 22.6, 15.2, 21.7, 19.2, 43.8, 20.3,
#        33.2, 19.9, 22.5, 32.7, 22. , 17.1, 19. , 15. , 16.1, 25.1, 23.7,
#        28.7, 37.2, 22.6, 16.4, 25. , 29.8, 22.1, 17.4, 18.1, 30.3, 17.5,
#        24.7, 12.6, 26.5, 28.7, 13.3, 10.4, 24.4, 23. , 20. , 17.8,  7. ,
#        11.8, 24.4, 13.8, 19.4, 25.2, 19.4, 19.4, 29.1])

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# **Normalizing the data**

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %% [markdown]
# ### Building your model

# %% [markdown]
# **Model definition**

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
    return model

# %% [markdown]
# ### Validating your approach using K-fold validation

# %% [markdown]
# **K-fold validation**

# %%
k = 4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=16, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %%
all_scores
# Out:
# [2.051968812942505, 2.511878252029419, 2.4386701583862305, 2.5340511798858643]

# %%
np.mean(all_scores)
# Out:
# 2.3841421008110046

# %% [markdown]
# **Saving the validation logs at each fold**

# %%
num_epochs = 500
all_mae_histories = []
for i in range(k):
    print(f"Processing fold #{i}")
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)
    model = build_model()
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=16, verbose=0)
    mae_history = history.history["val_mae"]
    all_mae_histories.append(mae_history)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3

# %% [markdown]
# **Building the history of successive mean K-fold validation scores**

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %% [markdown]
# **Plotting validation scores**

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Plotting validation scores, excluding the first 10 data points**

# %%
truncated_mae_history = average_mae_history[10:]
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()

# %% [markdown]
# **Training the final model**

# %%
model = build_model()
model.fit(train_data, train_targets,
          epochs=130, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 15.7148 - mae: 2.6006

# %%
test_mae_score
# Out:
# 2.600606679916382

# %% [markdown]
# ### Generating predictions on new data

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# array([8.471721], dtype=float32)

# %%
# Out:
# 404

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# ## Summary
